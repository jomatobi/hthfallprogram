# %%
import pandas
import seaborn
import matplotlib.pyplot as plt

''' 
The best way to complete this activity is to copy the code in this file into a jupyter notebook file you create. This will also you to see your visualizations easier. Once you have finished creating your visuals copy your code back into this file and submit it to Replit. Don't forget to also upload your new code to Github! 
'''
# call in our titanic csv
titanic_data = pandas.read_csv("titanic.csv")
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Step 1: Create a heatmap showing the correlation between the following features: survival, pclass, sex, age, and fare 

titanic_features = titanic_data[["Survived", "Pclass", "Sex", "Age", "Fare"]]

seaborn.heatmap(titanic_features.corr(), annot = True, cmap = 'rocket')
plt.show()
# Out:
# C:\Users\Joan\AppData\Local\Temp\ipykernel_11452\1070896528.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   seaborn.heatmap(titanic_features.corr(), annot = True, cmap = 'rocket')

# %%
# Step 2: Create a bar graph that illustrates how many passengers fell into each of these age ranges: 0 - 16, 17 - 25, 26 -40, 41 - 59, 60 or older
# age_group_chart =
# titanic_maxage = titanic_data[]

age_groups = {
    
    "groups": [
        "16 or younger",
        "17 to 25",
        "26 to 40",
        "41 to 60",
        "60+"
    ],
    
    "count": [
        len( titanic_data[ (titanic_data["Age"] >= 0) & (titanic_data["Age"] <= 16) ]),
        len( titanic_data[ (titanic_data["Age"] >= 17) & (titanic_data["Age"] <= 25) ]),
        len( titanic_data[ (titanic_data["Age"] >= 26) & (titanic_data["Age"] <= 40) ]),
        len( titanic_data[ (titanic_data["Age"] >= 41) & (titanic_data["Age"] <= 59) ]),
        len( titanic_data[ (titanic_data["Age"] >= 60 )])],
}
vis_df = pandas.DataFrame(age_groups)
seaborn.barplot(data = vis_df, x = 'groups', y = 'count')
plt.show()

# %%
# Step 3: Create a line graph showing the average survival percentage of each of the previous age groups
# survival_age_pers = 

survival_age= {
    
    "groups": [
        "16 or younger",
        "17 to 25",
        "26 to 40",
        "41 to 60",
        "60+"
    ],
    
    "mean_survival": [

        titanic_data[ titanic_data["Age"] >= 0 & (titanic_data["Age"] <= 16) ]['Survived'].mean(),
        titanic_data[ titanic_data["Age"] >= 17 & (titanic_data["Age"] <= 25) ]['Survived'].mean(),
        titanic_data[ titanic_data["Age"] >= 26 & (titanic_data["Age"] <= 40) ]['Survived'].mean(),    
        titanic_data[ titanic_data["Age"] >= 41 & (titanic_data["Age"] <= 59) ]['Survived'].mean(),
        titanic_data[ titanic_data["Age"] >= 60 ]['Survived'].mean()]
    }

vis_df = pandas.DataFrame(survival_age)     
seaborn.lineplot(data = vis_df, x = 'groups', y = 'mean_survival')
plt.show()

# %%
# Step 4: Create a pie chart that shows the percentage of survivors that were male and the percentage of survivors that were female
# survivors = 


# male_survivors = titanic_data[ titanic_data["Sex"] == "male"]['Survived']
# fem_survivors = titanic_data[ titanic_data["Sex"] == "female"]['Survived']

# survival_count = 0
# for survival in mf_survivors:
#     if (survival == 1):
#         survival_count += 1
                
# data = [survival_count/len(titanic_data[ titanic_data['Sex'] == 'female'])*100,
# survival_count/len(titanic_data[ titanic_data['Sex'] == 'male'])*100]

male_survivors = titanic_data[ titanic_data['Sex'] == "male"]["Survived"].mean()
fem_survivors = titanic_data[ titanic_data['Sex'] == "female"]["Survived"].mean()
data = [male_survivors, fem_survivors]

keys = ['male', 'female']
    
vis_df = pandas.DataFrame(mf_survivors)
plt.pie(x = data, labels=keys)
plt.show

# mf_survivors = pandas.read_csv("titanic_data")



# # Sex
# # 'male'
# # 'female'
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
male_survivors = titanic_data[ titanic_data["Sex"] == "male"]['Survived']
fem_survivors = titanic_data[ titanic_data["Sex"] == "female"]['Survived']
male_survivors
# Out:
# 0      0
# 4      0
# 5      0
# 6      0
# 7      0
#       ..
# 883    0
# 884    0
# 886    0
# 889    1
# 890    0
# Name: Survived, Length: 577, dtype: int64

# %%
# Step 5: Create a histogram that shows the distribution of passengers between the three embarking locations: C (Cherbourg), Q (Queenstown), S (Southampton)
# titanic_description = 



# cherbourg_passengers = titanic_data[ titanic_data['Embarked'] == 'C']
# }

seaborn.histplot(titanic_data['Embarked'])
# Out:
# <AxesSubplot: xlabel='Embarked', ylabel='Count'>
