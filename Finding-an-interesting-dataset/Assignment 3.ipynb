# %%
import pandas

# pandas.options.display.max_columns = None
# pandas.options.display.max_rows = None

csv_data = pandas.read_csv("imdb_top_1000.csv")
csv_data['Gross'] = csv_data['Gross'].str.replace(',', '').astype(float)
csv_data
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
# Question 1: How many movies have a perfect IMDB metascore (100)?
perfect_meta_score = csv_data[csv_data['Meta_score'] == 100.0]
perfect_meta_score

# Answer: 12
# Out:
#                                            Poster_Link  \
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 50   https://m.media-amazon.com/images/M/MV5BY2IzZG...
# 81   https://m.media-amazon.com/images/M/MV5BNGUxYW...
# 116  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 119  https://m.media-amazon.com/images/M/MV5BYTE4OD...
# 124  https://m.media-amazon.com/images/M/MV5BYjBiOT...
# 260  https://m.media-amazon.com/images/M/MV5BYTg1Mm...
# 274  https://m.media-amazon.com/images/M/MV5BZmQzMD...
# 423  https://m.media-amazon.com/images/M/MV5BODFlYz...
# 440  https://m.media-amazon.com/images/M/MV5BMjE5NT...
# 491  https://m.media-amazon.com/images/M/MV5BMTYzND...
# 559  https://m.media-amazon.com/images/M/MV5BYTc1NG...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 1             The Godfather          1972           A  175 min
# 50               Casablanca          1942           U  102 min
# ...

# %%
# Question 2: How many movies have a perfect IMDB rating? (10)
perfect_IMDB_rating = csv_data[csv_data['IMDB_Rating'] == 10.0]
perfect_IMDB_rating
# Answer: None
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %%
#  Question 3: Which director has received the highest average IMDB rating from their movies?
poor_directrate = csv_data.groupby('Director')['IMDB_Rating'].mean().idxmax()
poor_directrate

# Answer: Frank Darabont
# Out:
# 'Frank Darabont'

# %%
# csv_data.groupby('Star1')['Meta_score'].mean().filter()

# %%
# Question 4: Which actor appeared in the most movies with the average metascore ranking of >90?
# meta_actor = { [[csv_data.groupby('Star1')['Meta_score'].mean()]], 
#               [[csv_data.groupby('Star2')['Meta_score'].mean()]], 
#               [[csv_data.groupby('Star3')['Meta_score'].mean()]],
#              [[csv_data.groupby('Star4')['Meta_score'].mean()]]}
                                 

meta_star1 = csv_data[csv_data['Meta_score'] > 90]['Star1'].value_counts()
meta_star2 = csv_data[csv_data['Meta_score'] > 90]['Star2'].value_counts()
meta_star3 = csv_data[csv_data['Meta_score'] > 90]['Star3'].value_counts()
meta_star4 = csv_data[csv_data['Meta_score'] > 90]['Star4'].value_counts()


meta_star1
# star1 = Humprhry Bogart with 4 movies
meta_star2
# star 2 = Joseph Cotten with 3 movies
meta_star3
# star 3 = Vera Miles with 3 movies
meta_star4
# star 4 = Yvonne Furneaux with 2 movies

# final answer = Humphrey Bogart?
# Out:
# Yvonne Furneaux    2
# Ruth Hussey        1
# Ward Bond          1
# Angela Lansbury    1
# Edmond O'Brien     1
#                   ..
# Celeste Holm       1
# Takashi Shimura    1
# Janine Darcey      1
# George Raft        1
# Godfrey Tearle     1
# Name: Star4, Length: 131, dtype: int64

# %%
# Question 5: How many actors have a movie of >90 for their metascore across the movies they've been in?
actor_average1 = csv_data[csv_data['Meta_score'] > 90]['Star1'].value_counts()
actor_average1
# actor_average1 =  length = 108
actor_average2 = csv_data[csv_data['Meta_score'] > 90]['Star2'].value_counts()
actor_average2
# actor_average1 =  length = 123

actor_average3 = csv_data[csv_data['Meta_score'] > 90]['Star3'].value_counts()
actor_average3
# actor_average1 =  length = 125

actor_average4 = csv_data[csv_data['Meta_score'] > 90]['Star4'].value_counts()
actor_average4
# actor_average1 =  length = 131

# add lengths across outputs = 108 + 123 + 125 + 131 = 487 stars have a movie with a meta score of mroe than 90
# Out:
# Yvonne Furneaux    2
# Ruth Hussey        1
# Ward Bond          1
# Angela Lansbury    1
# Edmond O'Brien     1
#                   ..
# Celeste Holm       1
# Takashi Shimura    1
# Janine Darcey      1
# George Raft        1
# Godfrey Tearle     1
# Name: Star4, Length: 131, dtype: int64

# %%
# Question 6: What is the highest grossing movie from this list?
#highest_gross = csv_data.max("Gross")
# col = "Gross"
# highest_gross = csv_data.loc[csv_data[col].idxmax()]
csv_data.iloc[csv_data['Gross'].idxmax()]['Series_Title']
# Out:
# 'Star Wars: Episode VII - The Force Awakens'

# %%
# Question 9: Which actor has the highest total gross amount for all the movies they starred in?
actor_gross = {}
for index, series in csv_data.iterrows():
    actor_name = series['Star4']
    current_gross = series['Gross']
    if (actor in actor_gross.keys()):
        actor_gross[actor_name] += current_gross
    else:
        actor_gross[actor_name] = current_gross
actor_gross_series = pandas.Series(actor_gross)
actor_gross_series.idxmax()
actor_gross
# Answer for star 4 = Domhnall Gleeson
# Out:
# {'William Sadler': 28341469.0,
#  'Diane Keaton': 57300000.0,
#  'Michael Caine': 128261724.0,
#  'John Fiedler': 4360000.0,
#  'Orlando Bloom': 342551365.0,
#  'Bruce Willis': 107928762.0,
#  'Caroline Goodall': 96898818.0,
#  'Ken Watanabe': 292576195.0,
#  'Zach Grenier': 37030102.0,
#  'Sean Bean': 315544750.0,
#  'Sally Field': 330252182.0,
#  'Aldo Giuffrè': 6100000.0,
#  'Carrie-Anne Moss': 171479930.0,
#  'Lorraine Bracco': 46836394.0,
#  'Billy Dee Williams': 309125409.0,
#  'Peter Brocco': 112000000.0,
#  'Renée Elise Goldsberry': nan,
#  'Choi Woo-sik': 53367844.0,
#  'Aparna Balamurali': nan,
#  'Mackenzie Foy': 188020017.0,
#  'Matheus Nachtergaele': 7563397.0,
#  'Rumi Hiiragi': 10055859.0,
#  'Edward Burns': 216540909.0,
#  'Bonnie Hunt': 136801374.0,
#  'Giustino Durano': 57598247.0,
#  'Andrew Kevin Walker': 100125643.0,
#  'Kasi Lemmons': 130742922.0,
#  'Alec Guinness': 322740140.0,
#  'Tetsurô Tanba': nan,
#  'Yukiko Shimazaki': 269061.0,
# ...

# %%
# Question 10: Which director achieved the highest gross amount for all the movies they directed?
director_gross = {}
for index, series in csv_data.iterrows():
    director_name = series['Director']
    current_gross = series['Gross']
    if (director_name in director_gross.keys()):
        director_gross[director_name] += current_gross
    else:
        director_gross[director_name] = current_gross
director_gross_series = pandas.Series(director_gross)
director_gross_series.idxmax()
# director_gross
# Answer = Steven Spielberg
# Out:
# 'Steven Spielberg'

# %%
# Question 7: Which celebrities appeared in multiple movies with the same director?

# %%
csv_data['Director'].unique()

# %%
# Question 8: Which combination of actors received a high gross for their movie?
# use tuple of actors as a key, and make sure it's sorted
# copy question 10's format
