# %%
import pandas

# pandas.options.display.max_columns = None
# pandas.options.display.max_rows = None

csv_data = pandas.read_csv("imdb_top_1000.csv")
csv_data
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# 3      The Godfather: Part II          1974           A  202 min
# 4                12 Angry Men          1957           U   96 min
# ..                        ...           ...         ...      ...
# 995    Breakfast at Tiffany's          1961           A  115 min
# 996                     Giant          1956           G  201 min
# 997     From Here to Eternity          1953      Passed  118 min
# 998                  Lifeboat          1944         NaN   97 min
# 999              The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ..                        ...          ...
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# 999  Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 0    Two imprisoned men bond over a number of years...        80.0
# 1    An organized crime dynasty's aging patriarch t...       100.0
# 2    When the menace known as the Joker wreaks havo...        84.0
# 3    The early life and career of Vito Corleone in ...        90.0
# 4    A jury holdout attempts to prevent a miscarria...        96.0
# ..                                                 ...         ...
# 995  A young New York socialite becomes interested ...        76.0
# 996  Sprawling epic covering the life of a Texas ca...        84.0
# 997  In Hawaii in 1941, a private is cruelly punish...        85.0
# 998  Several survivors of a torpedoed merchant ship...        78.0
# 999  A man in London tries to help a counter-espion...        93.0
#
#                  Director              Star1              Star2  \
# 0          Frank Darabont        Tim Robbins     Morgan Freeman
# 1    Francis Ford Coppola      Marlon Brando          Al Pacino
# 2       Christopher Nolan     Christian Bale       Heath Ledger
# 3    Francis Ford Coppola          Al Pacino     Robert De Niro
# 4            Sidney Lumet        Henry Fonda        Lee J. Cobb
# ..                    ...                ...                ...
# 995         Blake Edwards     Audrey Hepburn     George Peppard
# 996        George Stevens   Elizabeth Taylor        Rock Hudson
# 997        Fred Zinnemann     Burt Lancaster   Montgomery Clift
# 998      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 999      Alfred Hitchcock       Robert Donat  Madeleine Carroll
#
#               Star3           Star4  No_of_Votes        Gross
# 0        Bob Gunton  William Sadler      2343110   28,341,469
# 1        James Caan    Diane Keaton      1620367  134,966,411
# 2     Aaron Eckhart   Michael Caine      2303232  534,858,444
# 3     Robert Duvall    Diane Keaton      1129952   57,300,000
# 4     Martin Balsam    John Fiedler       689845    4,360,000
# ..              ...             ...          ...          ...
# 995   Patricia Neal     Buddy Ebsen       166544          NaN
# 996      James Dean   Carroll Baker        34075          NaN
# 997    Deborah Kerr      Donna Reed        43374   30,500,000
# 998   Walter Slezak  William Bendix        26471          NaN
# 999  Lucie Mannheim  Godfrey Tearle        51853          NaN
#
# [1000 rows x 16 columns]

# %%
# Question 1: How many movies have a perfect IMDB metascore (100)?
perfect_meta_score = csv_data[csv_data['Meta_score'] == 100.0]
perfect_meta_score

# Answer: 12
# Out:
#                                            Poster_Link  \
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 50   https://m.media-amazon.com/images/M/MV5BY2IzZG...
# 81   https://m.media-amazon.com/images/M/MV5BNGUxYW...
# 116  https://m.media-amazon.com/images/M/MV5BYWY5Zj...
# 119  https://m.media-amazon.com/images/M/MV5BYTE4OD...
# 124  https://m.media-amazon.com/images/M/MV5BYjBiOT...
# 260  https://m.media-amazon.com/images/M/MV5BYTg1Mm...
# 274  https://m.media-amazon.com/images/M/MV5BZmQzMD...
# 423  https://m.media-amazon.com/images/M/MV5BODFlYz...
# 440  https://m.media-amazon.com/images/M/MV5BMjE5NT...
# 491  https://m.media-amazon.com/images/M/MV5BMTYzND...
# 559  https://m.media-amazon.com/images/M/MV5BYTc1NG...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 1             The Godfather          1972           A  175 min
# 50               Casablanca          1942           U  102 min
# 81              Rear Window          1954           U  112 min
# 116      Lawrence of Arabia          1962           U  228 min
# 119                 Vertigo          1958           A  128 min
# 124            Citizen Kane          1941          UA  119 min
# 260   Trois couleurs: Rouge          1994           U   99 min
# 274     Fanny och Alexander          1982           A  188 min
# 423          Il conformista          1970          UA  113 min
# 440  Sweet Smell of Success          1957    Approved   96 min
# 491                 Boyhood          2014           A  165 min
# 559               Notorious          1946           U  102 min
#
#                            Genre  IMDB_Rating  \
# 1                   Crime, Drama          9.2
# 50           Drama, Romance, War          8.5
# 81             Mystery, Thriller          8.4
# 116  Adventure, Biography, Drama          8.3
# 119   Mystery, Romance, Thriller          8.3
# 124               Drama, Mystery          8.3
# 260      Drama, Mystery, Romance          8.1
# 274                        Drama          8.1
# 423                        Drama          8.0
# 440             Drama, Film-Noir          8.0
# 491                        Drama          7.9
# 559    Drama, Film-Noir, Romance          7.9
#
#                                               Overview  Meta_score  \
# 1    An organized crime dynasty's aging patriarch t...       100.0
# 50   A cynical expatriate American cafe owner strug...       100.0
# 81   A wheelchair-bound photographer spies on his n...       100.0
# 116  The story of T.E. Lawrence, the English office...       100.0
# 119  A former police detective juggles wrestling wi...       100.0
# 124  Following the death of publishing tycoon Charl...       100.0
# 260  A model discovers a retired judge is keen on i...       100.0
# 274  Two young Swedish children experience the many...       100.0
# 423  A weak-willed Italian man becomes a fascist fl...       100.0
# 440  Powerful but unethical Broadway columnist J.J....       100.0
# 491  The life of Mason, from early childhood to his...       100.0
# 559  A woman is asked to spy on a group of Nazi fri...       100.0
#
#                   Director                   Star1                   Star2  \
# 1     Francis Ford Coppola           Marlon Brando               Al Pacino
# 50          Michael Curtiz         Humphrey Bogart          Ingrid Bergman
# 81        Alfred Hitchcock           James Stewart             Grace Kelly
# 116             David Lean           Peter O'Toole           Alec Guinness
# 119       Alfred Hitchcock           James Stewart               Kim Novak
# 124           Orson Welles            Orson Welles           Joseph Cotten
# 260   Krzysztof Kieslowski             Irène Jacob  Jean-Louis Trintignant
# 274         Ingmar Bergman             Bertil Guve         Pernilla Allwin
# 423    Bernardo Bertolucci  Jean-Louis Trintignant      Stefania Sandrelli
# 440  Alexander Mackendrick          Burt Lancaster             Tony Curtis
# 491      Richard Linklater          Ellar Coltrane       Patricia Arquette
# 559       Alfred Hitchcock              Cary Grant          Ingrid Bergman
#
#                   Star3              Star4  No_of_Votes        Gross
# 1            James Caan       Diane Keaton      1620367  134,966,411
# 50         Paul Henreid       Claude Rains       522093    1,024,560
# 81        Wendell Corey      Thelma Ritter       444074   36,764,313
# 116       Anthony Quinn       Jack Hawkins       268085   44,824,144
# 119  Barbara Bel Geddes        Tom Helmore       364368    3,200,000
# 124   Dorothy Comingore    Agnes Moorehead       403351    1,585,634
# 260    Frédérique Feder  Jean-Pierre Lorit        90729    4,043,686
# 274  Kristina Adolphson     Börje Ahlstedt        57784    4,971,340
# 423     Gastone Moschin      Enzo Tarascio        27067      541,940
# 440      Susan Harrison      Martin Milner        28137          NaN
# 491         Ethan Hawke       Elijah Smith       335533   25,379,975
# 559        Claude Rains      Louis Calhern        92306   10,464,000

# %%
# Question 2: How many movies have a perfect IMDB rating? (10)
perfect_IMDB_rating = csv_data[csv_data['IMDB_Rating'] == 10.0]
perfect_IMDB_rating
# Answer: None
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross]
# Index: []

# %%
#  Question 3: Which director has received the highest average IMDB rating from their movies?
poor_directrate = csv_data.groupby('Director')['IMDB_Rating'].mean()
poor_directrate

# Answer: Aamir Khan
# Out:
# Director
# Aamir Khan             8.40
# Aaron Sorkin           7.80
# Abdellatif Kechiche    7.70
# Abhishek Chaubey       7.80
# Abhishek Kapoor        7.70
#                        ...
# Zack Snyder            7.60
# Zaza Urushadze         8.20
# Zoya Akhtar            8.05
# Çagan Irmak            8.30
# Ömer Faruk Sorak       8.00
# Name: IMDB_Rating, Length: 548, dtype: float64

# %%
# Question 4: Which actor appeared in the most movies with the average metascore ranking of >90?
meta_actor = { [[csv_data.groupby('Star1')['Meta_score'].mean]], 
              [[csv_data.groupby('Star2')['Meta_score'].mean]], 
              [[csv_data.groupby('Star3')['Meta_score'].mean]],
             [[csv_data.groupby('Star4')['Meta_score'].mean]]}
                                 
meta_actor
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [43], line 2
#       1 # Question 4: Which actor appeared in the most movies with the average metascore ranking of >90?
# ----> 2 meta_actor = { [[csv_data.groupby('Star1')['Meta_score'].mean]],
#       3               [[csv_data.groupby('Star2')['Meta_score'].mean]],
#       4               [[csv_data.groupby('Star3')['Meta_score'].mean]],
#       5              [[csv_data.groupby('Star4')['Meta_score'].mean]]}
#       7 meta_actor
#
# TypeError: unhashable type: 'list'

# %%
# Question 5: How many actors have an average of >90 for their metascore across the movies they've been in?
actor_average = {[csv_data]
    
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [34], line 2
#       1 # Question 5: How many actors have an average of >90 for their metascore across the movies they've been in?
# ----> 2 actor_average = {[csv_data]
#       3
#       4 }
#
# TypeError: unhashable type: 'list'

# %%
# Question 6: What is the highest grossing movie from this list?
highest_gross = csv_data.max("Gross")
col = "Gross"
highest_gross = csv_data.loc[csv_data[col].idxmax()]
highest_gross
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 'Gross'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [44], line 2
#       1 # Question 6: What is the highest grossing movie from this list?
# ----> 2 highest_gross = csv_data.max("Gross")
#       3 col = "Gross"
#       4 highest_gross = csv_data.loc[csv_data[col].idxmax()]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11941, in NDFrame._add_numeric_operations.<locals>.max(self, axis, skipna, level, numeric_only, **kwargs)
#   11921 @doc(
#   11922     _num_doc,
#   11923     desc="Return the maximum of the values over the requested axis.\n\n"
#    (...)
#   11939     **kwargs,
#   11940 ):
# > 11941     return NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11383, in NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#   11375 def max(
#   11376     self,
#   11377     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11381     **kwargs,
#   11382 ):
# > 11383     return self._stat_function(
#   11384         "max",
#   11385         nanops.nanmax,
#   11386         axis,
#   11387         skipna,
#   11388         level,
#   11389         numeric_only,
#   11390         **kwargs,
#   11391     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10798, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10795         self = type(self)(mgr)
#   10797 # TODO: Make other agg func handle axis=None properly GH#21597
# > 10798 axis = self._get_axis_number(axis)
#   10799 labels = self._get_agg_axis(axis)
#   10800 assert axis in [0, 1]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:556, in NDFrame._get_axis_number(cls, axis)
#     554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
# --> 556     raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# ValueError: No axis named Gross for object type DataFrame

# %%
# Question 7: Which celebrities appeared in multiple movies with the same director?

# %%
# Question 8: hich combination of actors received a high gross for their movie?

# %%
# Question 9: Which actor has the highest total gross amount for all the movies they starred in?

# %%
# Question 10: Which director achieved the highest gross amount for all the movies they directed?
